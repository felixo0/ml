# %%
"""
simple demo of a horizontal bar chart
"""

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.rcdefaults()

# %%
fig, ax = plt.subplots()
# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

# %%
ax.barh(y_pos, performance, xerr=error, align='center',
       color='green', ecolor='black')
# Out:
# <Container object of 5 artists>

# %%
ax.set_yticks(y_pos)
# Out:
# [<matplotlib.axis.YTick at 0x10de4e978>,
#  <matplotlib.axis.YTick at 0x10e0892b0>,
#  <matplotlib.axis.YTick at 0x10de8b7f0>,
#  <matplotlib.axis.YTick at 0x10de82860>,
#  <matplotlib.axis.YTick at 0x10e28c278>]

# %%
ax.set_yticklabels(people)
# Out:
# [<matplotlib.text.Text at 0x10de66438>,
#  <matplotlib.text.Text at 0x10de6b128>,
#  <matplotlib.text.Text at 0x10de826a0>,
#  <matplotlib.text.Text at 0x10e28c0b8>,
#  <matplotlib.text.Text at 0x10e28ca90>]

# %%
ax.invert_yaxis()

# %%
ax.set_xlabel('Performance')

# %%
ax.set_title('How fast do you want to go today?')

# %%
plt.show()

# %%
x = np.linspace(0, 1, 500)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)
fig, ax = plt.subplots()
ax.fill(x, y, zorder=10)
ax.grid(True, zorder=5)
plt.show()
